# %%
from TPED.projects.GENE_sim_reader.src.GENE_nrg_data import GeneNrg as GN
from TPED.projects.GENE_sim_reader.utils.find_GENE_files import GeneFileFinder as GFF

import os

# %%
scan_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001'
gene_filepath = GFF(scan_path).find_files('nrg')[0]

print(gene_filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/nrg_0001

# %%
nrg = GN(gene_filepath)

input_quantities = ['Q_EM', 'Q_ES', 'Gamma_ES']

nrg_dict = nrg.nrg_filepath_to_dict(time_criteria='last', input_nrg_species=['e', 'i'], input_nrg_quantities = input_quantities)

# %%
for k in nrg_dict.keys():
    print(k)
# Out:
# time
# n_mag_i
# u_par_mag_i
# T_par_mag_i
# T_perp_mag_i
# Gamma_ES_i
# Gamma_EM_i
# Q_ES_i
# Q_EM_i
# Pi_ES_i
# Pi_EM_i
# n_mag_e
# u_par_mag_e
# T_par_mag_e
# T_perp_mag_e
# Gamma_ES_e
# Gamma_EM_e
# Q_ES_e
# Q_EM_e
# Pi_ES_e
# Pi_EM_e
# n_mag_c
# u_par_mag_c
# T_par_mag_c
# T_perp_mag_c
# Gamma_ES_c
# Gamma_EM_c
# Q_ES_c
# Q_EM_c
# Pi_ES_c
# Pi_EM_c

# %%
nrg.nrg_dict_to_xarray(nrg_dict)
# Out:
# <xarray.Dataset> Size: 56B
# Dimensions:     (time: 1)
# Coordinates:
#   * time        (time) float64 8B 17.75
# Data variables:
#     Gamma_ES_i  (time) float64 8B 49.91
#     Q_ES_i      (time) float64 8B 79.76
#     Q_EM_i      (time) float64 8B 326.4
#     Gamma_ES_e  (time) float64 8B 93.95
#     Q_ES_e      (time) float64 8B 1.396e+03
#     Q_EM_e      (time) float64 8B 4.208e+04
# Attributes:
#     filepath:   /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     directory:  /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     suffix:     0001
