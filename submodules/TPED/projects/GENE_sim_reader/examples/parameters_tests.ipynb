# %%
from TPED.projects.GENE_sim_reader.src.GENE_parameters_data import GeneParameters as GP
from TPED.projects.GENE_sim_reader.utils.find_GENE_files import GeneFileFinder as GFF

import os

# %%
scan_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001'
gene_filepath = GFF(scan_path).find_files()[0]

print(gene_filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/parameters_0001

# %%
parameter = GP(gene_filepath)

parameter_dict = parameter.parameters_filepath_to_dict()
parameter_dict
# Out:
# OrderedDict([('n_procs_s', 1),
#              ('n_procs_v', 2),
#              ('n_procs_w', 4),
#              ('n_procs_x', 1),
#              ('n_procs_y', 1),
#              ('n_procs_z', 32),
#              ('n_procs_sim', 256),
#              ('n_parallel_sims', 18),
#              ('n_spec', 3),
#              ('nx0', 7),
#              ('nky0', 1),
#              ('nz0', 1024),
#              ('nv0', 36),
#              ('nw0', 8),
#              ('kymin', 0.8),
#              ('lv', 3.0),
#              ('lw', 9.0),
#              ('adapt_lx', True),
#              ('x0', 0.736),
#              ('n0_global', 14),
#              ('ky0_ind', 1),
#              ('diagdir',
#               '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/'),
#              ('read_checkpoint', False),
#              ('write_checkpoint', True),
#              ('istep_field', 100),
#              ('istep_mom', 600),
#              ('istep_nrg', 50),
#              ('istep_omega', 20),
#              ('istep_vsp', 5000),
#              ('istep_schpt', 5000),
#              ('istep_energy', 100),
#              ('write_std', True),
#              ('iterdb_file',
#               '/global/homes/j/joeschm/data/ST_research/NSTXU_discharges/132588/NSTXU132588.iterdb'),
#              ('nonlinear', False),
#              ('comp_type', 'IV'),
#              ('perf_vec', '1 2 2 3 1 2 2 2 2'),
#              ('nblocks', 6),
#              ('arakawa_zv', False),
#              ('timescheme', 'RK4'),
#              ('dt_max', 7.81e-05),
#              ('dt_vlasov', 7.81e-05),
#              ('ev_coll', 504.55),
#              ('timelim', 8600000),
#              ('ntimesteps', 20000000),
#              ('beta', 0.13158615),
#              ('debye2', 6.7188926e-06),
#              ('collision_op', 'landau'),
#              ('coll', 0.0028101088),
#              ('coll_cons_model', 'xu_rosenbluth'),
#              ('init_cond', 'alm'),
#              ('hyp_z_with_dz_prefactor', False),
#              ('hyp_z', 1.0),
#              ('hyp_v_with_dv_prefactor', False),
#              ('hyp_v', 0.2),
#              ('perf_tsteps', -1),
#              ('magn_geometry', 'tracer_efit'),
#              ('q0', 3.9979606),
#              ('shat', 1.5071461),
#              ('geomdir',
#               '/global/homes/j/joeschm/data/ST_research/NSTXU_discharges/132588/'),
#              ('geomfile', 'g132588.00650'),
#              ('edge_opt', 4.0),
#              ('minor_r', 1.0),
#              ('major_R', 0.94126021),
#              ('rhostar', 0.01049004),
#              ('dpdx_term', 'full_drift'),
#              ('dpdx_pm', 1.5026869),
#              ('norm_flux_projection', False),
#              ('name1', 'i'),
#              ('omn1', 4.3000201),
#              ('omt1', 1.9235838),
#              ('mass1', 1.0),
#              ('temp1', 0.9821114),
#              ('dens1', 0.4932987),
#              ('charge1', 1.0),
#              ('name2', 'e'),
#              ('omn2', 3.4119324),
#              ('omt2', 3.278125),
#              ('mass2', 0.0002724),
#              ('temp2', 1.0),
#              ('dens2', 1.0),
#              ('charge2', -1.0),
#              ('name3', 'c'),
#              ('omn3', 2.5473353),
#              ('omt3', 1.9235838),
#              ('mass3', 6.0),
#              ('temp3', 0.9821114),
#              ('dens3', 0.084450216),
#              ('charge3', 6.0),
#              ('step_time', 0.0165),
#              ('number of computed time steps', 227219),
#              ('time for initial value solver', 3752.392),
#              ('calc_dt', True),
#              ('nltdt_off', False),
#              ('ev_coll_est', 627.29539),
#              ('init_time', 1.0159),
#              ('n_fields', 2),
#              ('n_moms', 6),
#              ('nrgcols', 10),
#              ('lx', 0.829382),
#              ('ly', 7.85398),
#              ('PRECISION', 'DOUBLE'),
#              ('ENDIANNESS', 'LITTLE'),
#              ('OMP_NUM_THREADS', 1),
#              ('GIT_BRANCH',
#               '4ee4f597491b9fc7e6850309318f931f2b98ca17                    '),
#              ('RELEASE', '2.0 - patch 4'),
#              ('nu_ei', 2.406498),
#              ('nustar_i', 0.11921),
#              ('nustar_e', 0.162611),
#              ('Bref', 0.3598016468783417),
#              ('Tref', 0.8288609856954336),
#              ('nref', 5.09975977623404),
#              ('Lref', 1.1003037380870726),
#              ('mref', 2.0),
#              ('is_bsg', False),
#              ('filepath',
#               '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/parameters_0001')])

# %%
param_xarray = parameter.parameters_dict_to_xarray(parameter_dict)
param_xarray
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:                        ()
# Data variables: (12/114)
#     n_procs_s                      int64 8B 1
#     n_procs_v                      int64 8B 2
#     n_procs_w                      int64 8B 4
#     n_procs_x                      int64 8B 1
#     n_procs_y                      int64 8B 1
#     n_procs_z                      int64 8B 32
#     ...                             ...
#     Bref                           float64 8B 0.3598
#     Tref                           float64 8B 0.8289
#     nref                           float64 8B 5.1
#     Lref                           float64 8B 1.1
#     mref                           float64 8B 2.0
#     is_bsg                         bool 1B False
# Attributes:
#     filepath:   /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     directory:  /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     suffix:     0001

# %%
param_xarray = parameter.parameters_filepath_to_xarray()

param_xarray
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:                        ()
# Data variables: (12/114)
#     n_procs_s                      int64 8B 1
#     n_procs_v                      int64 8B 2
#     n_procs_w                      int64 8B 4
#     n_procs_x                      int64 8B 1
#     n_procs_y                      int64 8B 1
#     n_procs_z                      int64 8B 32
#     ...                             ...
#     Bref                           float64 8B 0.3598
#     Tref                           float64 8B 0.8289
#     nref                           float64 8B 5.1
#     Lref                           float64 8B 1.1
#     mref                           float64 8B 2.0
#     is_bsg                         bool 1B False
# Attributes:
#     filepath:   /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     directory:  /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     suffix:     0001
