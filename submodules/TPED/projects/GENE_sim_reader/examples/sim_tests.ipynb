# %%
from TPED.projects.GENE_sim_reader.src.GENE_sim_data import GeneSimulation as GS
from TPED.projects.GENE_sim_reader.utils.find_GENE_files import GeneFileFinder as GFF

import os

# %%
scan_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001'
gene_filepath = GFF(scan_path).find_files()[0]

print(gene_filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/parameters_0001

# %%
simulation = GS(gene_filepath)

input_quant_dict = {'species': 'e', 'nrg_quantities': ['Gamma_ES'], 'time_criteria': 'all'}

sim_xarray = simulation.simulation_to_xarray(['nrg'], input_quantities=input_quant_dict)
sim_xarray
# Out:
# <xarray.Dataset> Size: 75kB
# Dimensions:                        (time: 4546)
# Coordinates:
#   * time                           (time) float64 36kB 0.0 0.003905 ... 17.75
# Data variables: (12/115)
#     n_procs_s                      int64 8B 1
#     n_procs_v                      int64 8B 2
#     n_procs_w                      int64 8B 4
#     n_procs_x                      int64 8B 1
#     n_procs_y                      int64 8B 1
#     n_procs_z                      int64 8B 32
#     ...                             ...
#     Tref                           float64 8B 0.8289
#     nref                           float64 8B 5.1
#     Lref                           float64 8B 1.1
#     mref                           float64 8B 2.0
#     is_bsg                         bool 1B False
#     Gamma_ES_e                     (time) float64 36kB 0.0 -0.0002286 ... 93.95
# Attributes:
#     filepath:   /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
# ...

# %%
sim_xarray = simulation.simulation_to_xarray(['field'])
sim_xarray
# Out:
# <xarray.Dataset> Size: 289kB
# Dimensions:                        (time: 1, zgrid: 7168)
# Coordinates:
#   * time                           (time) float64 8B 17.75
#   * zgrid                          (zgrid) float64 57kB -7.0 -6.998 ... 6.998
# Data variables: (12/116)
#     n_procs_s                      int64 8B 1
#     n_procs_v                      int64 8B 2
#     n_procs_w                      int64 8B 4
#     n_procs_x                      int64 8B 1
#     n_procs_y                      int64 8B 1
#     n_procs_z                      int64 8B 32
#     ...                             ...
#     nref                           float64 8B 5.1
#     Lref                           float64 8B 1.1
#     mref                           float64 8B 2.0
#     is_bsg                         bool 1B False
#     field_phi                      (time, zgrid) complex128 115kB (1.20058189...
#     field_apar                     (time, zgrid) complex128 115kB (0.04086038...
# Attributes:
# ...

# %%
input_quant_dict = {'species': 'e', 'nrg_quantities': ['Gamma_ES'], 'time_criteria': 'all'}

sim_xarray = simulation.simulation_to_xarray(['nrg', 'field'], input_quantities=input_quant_dict)
sim_xarray
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                        (time: 4546, zgrid: 7168)
# Coordinates:
#   * time                           (time) float64 36kB 0.0 0.003905 ... 17.75
#   * zgrid                          (zgrid) float64 57kB -7.0 -6.998 ... 6.998
# Data variables: (12/118)
#     n_procs_s                      int64 8B 1
#     n_procs_v                      int64 8B 2
#     n_procs_w                      int64 8B 4
#     n_procs_x                      int64 8B 1
#     n_procs_y                      int64 8B 1
#     n_procs_z                      int64 8B 32
#     ...                             ...
#     mref                           float64 8B 2.0
#     is_bsg                         bool 1B False
#     Gamma_ES_e                     (time) float64 36kB 0.0 -0.0002286 ... 93.95
#     field_phi                      (time, zgrid) complex128 521MB (-0.0542709...
#     field_apar                     (time, zgrid) complex128 521MB (3.32769860...
# ...
