# %%
from TPED.projects.GENE_sim_reader.src.GENE_omega_data import GeneOmega as GO
from TPED.projects.GENE_sim_reader.utils.find_GENE_files import GeneFileFinder as GFF

import os

# %%
scan_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001'
gene_filepath = GFF(scan_path).find_files('omega')[0]

print(gene_filepath)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/omega_0001

# %%
omega = GO(gene_filepath)

omega_dict = omega.omega_filepath_to_dict()
omega_dict
# Out:
# {'filepath': '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_1024_edgeopt_04/scanfiles0001/omega_0001',
#  'kymin': 0.8,
#  'gamma': 0.602,
#  'omega': -4.807}

# %%
omega_xarray = omega.omega_dict_to_xarray(omega_dict)
omega_xarray
# Out:
# <xarray.Dataset> Size: 24B
# Dimensions:  ()
# Data variables:
#     kymin    float64 8B 0.8
#     gamma    float64 8B 0.602
#     omega    float64 8B -4.807
# Attributes:
#     filepath:   /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     directory:  /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM...
#     suffix:     0001
