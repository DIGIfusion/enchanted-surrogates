# %%
from TPED.src.utils.GENE_file_functions.fieldlib import fieldfile
from TPED.src.utils.GENE_file_functions.dict_parameters_data import parameters_filepath_to_dict
from TPED.src.utils.file_functions import switch_suffix_file

from TPED.src.common_tools.calc_omega import calc_omega_from_field

from TPED.src.utils.GENE_file_functions.find_buried_filetypes import find_files

import numpy as np

# %%
# param_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_64_edgeopt_04/scanfiles0000/parameters_0001'

# param_dict = parameters_filepath_to_dict(param_path)

# field_path = switch_suffix_file(param_path, 'field')

# %%
scanfile_path = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q5_MTM_mode/convergence_check/nz0_edgeopt_hypz_scans_V3/nz0-256_edge_opt-8/scanfiles0001'

field_filepaths = find_files(scanfile_path, 'field')

len(field_filepaths)
# Out:
# 3

# %%
short_field_filepaths = field_filepaths[:100]
print(len(short_field_filepaths))
# Out:
# 3

# %%
for field_path in short_field_filepaths:
    calc_omega_from_field(field_path, calc_apar=True)
# Out:
# APAR - Gamma: -0.09692777358997151
# APAR - Omega: -7.166535069299665
# PHI - Gamma: -0.048655427557238694
# PHI - Omega: -7.138824950027088
# APAR - Gamma: 0.33166946056948954
# APAR - Omega: -0.9049107381541592
# PHI - Gamma: -0.04862092092555938
# PHI - Omega: -7.137024933537331
# APAR - Gamma: 0.03522227883003107
# APAR - Omega: -1.0641443366602157
# PHI - Gamma: -0.15329366367012487
# PHI - Omega: -7.353188568556999
